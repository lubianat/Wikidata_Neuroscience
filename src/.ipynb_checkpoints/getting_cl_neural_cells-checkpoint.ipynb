# %%
from pronto import Ontology

cl = Ontology("http://purl.obolibrary.org/obo/cl.obo")

# %%
cl['CL:0002116']
# Out:
# Term('CL:0002116', name='B220-low CD38-positive unswitched memory B cell')

# %%
from owlready2 import *
cl = get_ontology("https://github.com/obophenotype/cell-ontology/raw/master/cl-full.owl").load()

#onto = get_ontology("http://www.lesfleursdunormal.fr/static/_downloads/pizza_onto.owl")

obo = cl.get_namespace("http://purl.obolibrary.org/obo/")

# %%
cl.search(label = "neural cell")
# Out:
# [obo.CL_0002319]

# %%
neural_cell_iris = cl.search(subclass_of = obo.CL_0002319 )

# %%
neural_cell_names = []

for cell in neural_cell_iris:
    neural_cell_names.append(cell.label[0])

# %%
import pandas as pd

neural_cells = pd.DataFrame({"IRI":neural_cell_iris, "label":neural_cell_names})
# Out:
#                 IRI                                              label
# 0    obo.CL_0002319                                        neural cell
# 1    obo.CL_0000540                                             neuron
# 2    obo.CL_0000095                             neuron associated cell
# 3    obo.CL_0009004                                       retinal cell
# 4    obo.CL_0000878                  central nervous system macrophage
# 5    obo.CL_0000637        chromophil cell of anterior pituitary gland
# 6    obo.CL_0000652                                        pinealocyte
# 7    obo.CL_0000706                     choroid plexus epithelial cell
# 8    obo.CL_0000708                                leptomeningeal cell
# 9    obo.CL_0002169                 basal cell of olfactory epithelium
# 10   obo.CL_0002177  folliculostellate cell of pars distalis of ade...
# 11   obo.CL_0002549                       fibroblast of choroid plexus
# 12   obo.CL_0002575                    central nervous system pericyte
# 13   obo.CL_0002576                                    perineural cell
# 14   obo.CL_0002590        smooth muscle cell of the brain vasculature
# 15   obo.CL_1000298                     mesothelial cell of dura mater
# 16   obo.CL_1001602                   cerebral cortex endothelial cell
# 17   obo.CL_2000044               brain microvascular endothelial cell
# 18   obo.CL_0000028        CNS neuron (sensu Nematoda and Protostomia)
# 19   obo.CL_0000029                        neuron neural crest derived
# 20   obo.CL_0000099                                        interneuron
# 21   obo.CL_0000527                                    efferent neuron
# 22   obo.CL_0000526                                    afferent neuron
# 23   obo.CL_0000102                                   polymodal neuron
# 24   obo.CL_0000104                                  multipolar neuron
# 25   obo.CL_0000105                              pseudounipolar neuron
# 26   obo.CL_0000106                                    unipolar neuron
# 27   obo.CL_0000107                                   autonomic neuron
# 28   obo.CL_0000109                                  adrenergic neuron
# 29   obo.CL_0000110                                 peptidergic neuron
# ..              ...                                                ...
# 293  obo.CL_0000644                                Bergmann glial cell
# 294  obo.CL_0000645                                          pituicyte
# 295  obo.CL_0000683                                 ependymoglial cell
# 296  obo.CL_0002603                        astrocyte of the cerebellum
# 297  obo.CL_0002606                       astrocyte of the spinal cord
# 298  obo.CL_0002626                                 immature astrocyte
# 299  obo.CL_0002627                                   mature astrocyte
# 300  obo.CL_0012000                         astrocyte of the forebrain
# 301  obo.CL_2000025                        spinal cord oligodendrocyte
# 302  obo.CL_0000692                              terminal Schwann cell
# 303  obo.CL_0000687                              R1 photoreceptor cell
# 304  obo.CL_0000690                              R2 photoreceptor cell
# 305  obo.CL_0000694                              R3 photoreceptor cell
# 306  obo.CL_0000697                              R4 photoreceptor cell
# 307  obo.CL_0000702                              R5 photoreceptor cell
# 308  obo.CL_0000705                              R6 photoreceptor cell
# 309  obo.CL_0000707                              R7 photoreceptor cell
# 310  obo.CL_0000709                              R8 photoreceptor cell
# 311  obo.CL_2000019                    compound eye photoreceptor cell
# 312  obo.CL_0000490                        photopic photoreceptor cell
# 313  obo.CL_0000609                               vestibular hair cell
# 314  obo.CL_0002450                                        tether cell
# 315  obo.CL_2000034          anterior lateral line neuromast hair cell
# 316  obo.CL_2000037         posterior lateral line neuromast hair cell
# 317  obo.CL_0002085                                           tanycyte
# 318  obo.CL_0000495                  blue sensitive photoreceptor cell
# 319  obo.CL_0000496                 green sensitive photoreceptor cell
# 320  obo.CL_0000497                   red sensitive photoreceptor cell
# 321  obo.CL_0002069                    type II vestibular sensory cell
# 322  obo.CL_0002070                     type I vestibular sensory cell
#
# [323 rows x 2 columns]

# %%
# Out:
# [obo.CL_0002319]

# %%
onto.Pizza
# Out:
# pizza_onto.Pizza
